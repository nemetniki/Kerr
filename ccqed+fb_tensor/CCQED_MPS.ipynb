# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy as sc

mpl.rc('font',family='FreeSerif')
#mpl.rc('xtick',labelsize=20)
#mpl.rc('ytick',labelsize=20)
mpl.rc('text', usetex=True)
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
labfont  = {'fontname':'FreeSerif','fontsize':15}
titlefont  = {'fontname':'FreeSerif','fontsize':40}
colors={'red':(241/255.,88/255.,84/255.),\
        'orange':(250/255.,164/255.,58/255.),\
        'pink':(241/255.,124/255.,176/255.),\
        'brown':(178/255.,145/255.,47/255.),\
        'purple':(178/255.,118/255.,178/255.),\
        'green':(96/255.,189/255.,104/255.),\
        'blue':(93/255.,165/255.,218/255.),\
        'yellow':(222/255., 207/255., 63/255.),\
        'black':(0.,0.,0.)}
collab = ['green','blue','orange','red']
linew  = [5,6,5,6]
linest = ['-','--','-','--']
label_QM = "quantum linearized"
label_QM_sc = "scaled quantum linearized"
label_TM = "transfer matrix"
label_dat = "measured data"

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

num = 40
diss=True

Data = np.zeros((30001,8))
Data[:,:] = np.genfromtxt('../Data/CCQED+fb_%d.txt'%num)
Data2 = np.zeros((5001,6))
Data2[:,:] = np.genfromtxt('../Data/CCQED_MC40.txt')#%num)

if diss:
    Data3 = np.zeros((5001,5))
    Data3[:,:] = np.genfromtxt('../Data/CCQED_MC40_diss.txt')#%num)
fig0 = plt.figure(dpi=200)
ax0 = fig0.add_subplot(111)
ax0.grid(True)
_=ax0.set_xlabel("$t/\\tau$",**labfont)
_=ax0.set_ylabel("Norm",**labfont)
_=ax0.plot(Data[:-1,0],Data[:-1,1],ls=":",lw=4)
fig0.savefig("../Pictures/lin_ccqed/%d_norm.png"%num)

tau = .021

fig1 = plt.figure(dpi=200)
ax1 = fig1.add_subplot(111)
_=ax1.set_xlabel("$t/\\tau$",**labfont)
_=ax1.set_ylabel("Cavity occupation",**labfont)
_=ax1.plot(Data2[:-1,0]/tau,Data2[:-1,3],label="MC cav left")
_=ax1.plot(Data2[:-1,0]/tau,Data2[:-1,4],label="MC cav right")
if diss:
    _=ax1.plot(Data3[:-1,0]/tau,Data3[:-1,3],label="MC reservoir",ls="--")
#    _=ax1.plot(Data3[:-1,0]/tau,Data3[:-1,4],label="MC res right",ls="--")
ax1.grid(True)
_=ax1.plot(Data[:-1,0]/tau,Data[:-1,4],ls=":",lw=4,label="MPS left")
_=ax1.plot(Data[:-1,0]/tau,Data[:-1,5],ls=":",lw=4,label="MPS right")
_=ax1.set_xlim(0,500)
_=ax1.legend()
fig1.savefig("../Pictures/lin_ccqed/%d_cav.png"%num)

fig2 = plt.figure(dpi=200)
ax2 = fig2.add_subplot(111)
_=ax2.set_xlabel("$t/\\tau$",**labfont)
_=ax2.set_ylabel("Atomic population",**labfont)
_=ax2.plot(Data2[:-1,0]/tau,Data2[:-1,1],label="MC cav left")
_=ax2.plot(Data2[:-1,0]/tau,Data2[:-1,2],label="MC cav right")
if diss:
    _=ax2.plot(Data3[:-1,0]/tau,Data3[:-1,1],label="MC reservoir",ls="--")
#    _=ax2.plot(Data3[:-1,0]/tau,Data3[:-1,2],label="MC res right",ls="--")
ax2.grid(True)
_=ax2.plot(Data[:-1,0]/tau,Data[:-1,2],ls=":",lw=4,label="MPS left")
_=ax2.plot(Data[:-1,0]/tau,Data[:-1,3],ls=":",lw=4,label="MPS right")
_=ax2.set_xlim(0,1000)
_=ax2.legend()
fig2.savefig("../Pictures/lin_ccqed/%d_tls.png"%num)

fig3 = plt.figure(dpi=200)
ax3 = fig3.add_subplot(111)
_=ax3.set_xlabel("$t/\\tau$",**labfont)
_=ax3.set_ylabel("$g^{(2)}(t)$",**labfont)
_=ax3.plot(Data[:-1,0]/tau,Data[:-1,6],ls="-",lw=2,label="left")
_=ax3.plot(Data[:-1,0]/tau,Data[:-1,7],ls="--",lw=2,label="right")
_=ax3.legend()
#_=ax3.set_ylim(-.1,2.2)
#_=ax3.text(4.4,7.35, "$\phi=\pi$",fontsize=15, bbox=dict(boxstyle="round",facecolor="lightblue", alpha=0.5))
#_=ax3.text(7.5,1.9, "$\phi=0$",fontsize=15, bbox=dict(boxstyle="round",facecolor="lightblue", alpha=0.5))
#_=ax3.text(220,1.9, "$\phi=3\pi/2$",fontsize=15, bbox=dict(boxstyle="round",facecolor="lightblue", alpha=0.5))
ax3.grid(True)

fig3.savefig("../Pictures/lin_ccqed/%d_g2.png"%num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-6e2882be42a7> in <module>()
#       7
#       8 Data = np.zeros((30001,8))
# ----> 9 Data[:,:] = np.genfromtxt('../Data/CCQED+fb_%d.txt'%num)
#      10 Data2 = np.zeros((5001,6))
#      11 Data2[:,:] = np.genfromtxt('../Data/CCQED_MC40.txt')#%num)
#
# ValueError: could not broadcast input array from shape (1143,8) into shape (30001,8)

# %%
num = 40

num = [49,39,53]
shape = 30001
Data = np.zeros((1862,8))
Data[:,:] = np.genfromtxt('../Data/CCQED+fb_%d.txt'%num[0])
Data2 = np.zeros((2834,8))
Data2[:,:] = np.genfromtxt('../Data/CCQED+fb_%d.txt'%num[1])
Data3 = np.zeros((1501,8))
Data3[:,:] = np.genfromtxt('../Data/CCQED+fb_%d.txt'%num[2])

labels = ["$g\\tau=5$","$g\\tau=0.1$","$g\\tau=0.2$"]
#labels = ["$g\\tau=1.0$","$g\\tau=0.105$","$g\\tau=0.5$"]
#labels = ["$g\\tau=5.0$","$g\\tau=0.2$","$g\\tau=0.5$"]
#labels = ["$\phi=0$","$\phi=\pi/2$","$\phi=\pi$"]
#labels = ["left excited, both","right excited, both","right initial, no left"]

tau_case=True

tau=0.02
g=5

# %%
diss=False
fig1 = plt.figure(dpi=200)
ax1 = fig1.add_subplot(111)
if tau_case:
    _=ax1.set_xlabel("$gt$",**labfont)
    _=ax1.plot(Data3[:-1,0]*g,Data3[:-1,4],ls="-",lw=2,label=labels[0])
    _=ax1.plot(Data[:-1,0]*g,Data[:-1,4],ls="--",lw=2,label=labels[1])
    _=ax1.plot(Data2[:-1,0]*g,Data2[:-1,4],ls="-.",lw=2,label=labels[2])
else:
    _=ax1.set_xlabel("$t/\\tau$",**labfont)
    _=ax1.plot(Data[:-1,0]/tau,Data[:-1,4],ls="-",lw=2,label=labels[0])
    _=ax1.plot(Data2[:-1,0]/tau,Data2[:-1,4],ls="--",lw=2,label=labels[1])
    _=ax1.plot(Data3[:-1,0]/tau,Data3[:-1,4],ls="-.",lw=2,label=labels[2])
_=ax1.set_ylabel("Cavity 1 occupation",**labfont)
_=ax1.legend()
ax1.grid(True)
#_=ax1.set_ylim(-.02,.7)
#_=ax1.set_xlim(-0,1000.)
#_=ax1.set_xlim(-0,60.)
fig1.savefig("../Pictures/lin_ccqed/%d_%d_%d_cav1.png"%(num[0],num[1],num[2]))

fig2 = plt.figure(dpi=200)
ax2 = fig2.add_subplot(111)
if tau_case:
    _=ax2.set_xlabel("$gt$",**labfont)
    _=ax2.plot(Data3[:-1,0]*g,Data3[:-1,5],ls="-",lw=2,label=labels[0])
    _=ax2.plot(Data[:-1,0]*g,Data[:-1,5],ls="--",lw=2,label=labels[1])
    _=ax2.plot(Data2[:-1,0]*g,Data2[:-1,5],ls="-.",lw=2,label=labels[2])
else:
    _=ax2.set_xlabel("$t/\\tau$",**labfont)
    _=ax2.plot(Data[:-1,0]/tau,Data[:-1,5],ls="-",lw=2,label=labels[0])
    _=ax2.plot(Data2[:-1,0]/tau,Data2[:-1,5],ls="--",lw=2,label=labels[1])
    _=ax2.plot(Data3[:-1,0]/tau,Data3[:-1,5],ls="-.",lw=2,label=labels[2])
_=ax2.set_ylabel("Cavity 2 occupation",**labfont)
_=ax2.legend()
ax2.grid(True)
#_=ax2.set_ylim(-.02,.7)
#_=ax2.set_xlim(-0,1000.)
#_=ax2.set_xlim(-0,60.)
fig2.savefig("../Pictures/lin_ccqed/%d_%d_%d_cav2.png"%(num[0],num[1],num[2]))

fig3 = plt.figure(dpi=200)
ax3 = fig3.add_subplot(111)
if tau_case:
    _=ax3.set_xlabel("$gt$",**labfont)
    _=ax3.plot(Data3[:-1,0]*g,Data3[:-1,2],ls="-",lw=2,label=labels[0])
    _=ax3.plot(Data[:-1,0]*g,Data[:-1,2],ls="--",lw=2,label=labels[1])
    _=ax3.plot(Data2[:-1,0]*g,Data2[:-1,2],ls="-.",lw=2,label=labels[2])
else:
    _=ax3.set_xlabel("$t/\\tau$",**labfont)
    _=ax3.plot(Data[:-1,0]/tau,Data[:-1,2],ls="-",lw=2,label=labels[0])
    _=ax3.plot(Data2[:-1,0]/tau,Data2[:-1,2],ls="--",lw=2,label=labels[1])
    _=ax3.plot(Data3[:-1,0]/tau,Data3[:-1,2],ls="-.",lw=2,label=labels[2])
_=ax3.set_ylabel("Atomic population 1",**labfont)
_=ax3.legend()
ax3.grid(True)
_=ax3.set_ylim(-1.1,1.1)
#_=ax3.set_xlim(-0,1000.)
#_=ax3.set_xlim(-0,60.)
fig3.savefig("../Pictures/lin_ccqed/%d_%d_%d_tls1.png"%(num[0],num[1],num[2]))

fig4 = plt.figure(dpi=200)
ax4 = fig4.add_subplot(111)
if tau_case:
    _=ax4.set_xlabel("$gt$",**labfont)
    _=ax4.plot(Data3[:-1,0]*g,Data3[:-1,3],ls="-",lw=2,label=labels[0])
    _=ax4.plot(Data[:-1,0]*g,Data[:-1,3],ls="--",lw=2,label=labels[1])
    _=ax4.plot(Data2[:-1,0]*g,Data2[:-1,3],ls="-.",lw=2,label=labels[2])
else:
    _=ax4.set_xlabel("$t/\\tau$",**labfont)
    _=ax4.plot(Data[:-1,0]/tau,Data[:-1,3],ls="-",lw=2,label=labels[0])
    _=ax4.plot(Data2[:-1,0]/tau,Data2[:-1,3],ls="--",lw=2,label=labels[1])
    _=ax4.plot(Data3[:-1,0]/tau,Data3[:-1,3],ls="-.",lw=2,label=labels[2])
_=ax4.set_ylabel("Atomic population 2",**labfont)
_=ax4.legend()
ax4.grid(True)
_=ax4.set_ylim(-1.1,1.1)
#_=ax4.set_xlim(-0,1000.)
#_=ax4.set_xlim(-0,60.)
_=ax4.legend()
fig4.savefig("../Pictures/lin_ccqed/%d_%d_%d_tls2.png"%(num[0],num[1],num[2]))

fig5 = plt.figure(dpi=200)
ax5 = fig5.add_subplot(111)
if tau_case:
    _=ax5.set_xlabel("$gt$",**labfont)
    _=ax5.plot(Data3[:-1,0]*g,Data3[:-1,1],ls="-",lw=2,label=labels[0])
    _=ax5.plot(Data[:-1,0]*g,Data[:-1,1],ls="--",lw=2,label=labels[1])
    _=ax5.plot(Data2[:-1,0]*g,Data2[:-1,1],ls="-.",lw=2,label=labels[2])
else:
    _=ax5.set_xlabel("$t/\\tau$",**labfont)
    _=ax5.plot(Data[:-1,0]/tau,Data[:-1,1],ls="-",lw=2,label=labels[0])
    _=ax5.plot(Data2[:-1,0]/tau,Data2[:-1,1],ls="--",lw=2,label=labels[1])
    _=ax5.plot(Data3[:-1,0]/tau,Data3[:-1,1],ls="-.",lw=2,label=labels[2])
_=ax5.set_ylabel("Norm",**labfont)
_=ax5.legend()
ax5.grid(True)

fig6 = plt.figure(dpi=200)
ax6 = fig6.add_subplot(111)
if tau_case:
    _=ax6.set_xlabel("$gt$",**labfont)
    _=ax6.plot(Data3[:-1,0]*g,Data3[:-1,6],ls="-",lw=2,label=labels[0])
    _=ax6.plot(Data[:-1,0]*g,Data[:-1,6],ls="--",lw=2,label=labels[1])
    _=ax6.plot(Data2[:-1,0]*g,Data2[:-1,6],ls="-.",lw=2,label=labels[2])
else:
    _=ax6.set_xlabel("$t/\\tau$",**labfont)
    _=ax6.plot(Data[:-1,0]/tau,Data[:-1,6],ls="-",lw=2,label=labels[0])
    _=ax6.plot(Data2[:-1,0]/tau,Data2[:-1,6],ls="--",lw=2,label=labels[1])
    _=ax6.plot(Data3[:-1,0]/tau,Data3[:-1,6],ls="-.",lw=2,label=labels[2])
_=ax6.set_ylabel("$g^{(2)}_1$",**labfont)
_=ax6.legend()
ax6.grid(True)
_=ax6.set_ylim(-1,13.0)
#_=ax6.set_xlim(-0,200.)
_=ax6.set_xlim(-0,40.)
_=ax6.legend()
fig6.savefig("../Pictures/lin_ccqed/%d_%d_%d_g2_1.png"%(num[0],num[1],num[2]))

fig7 = plt.figure(dpi=200)
ax7 = fig7.add_subplot(111)
if tau_case:
    _=ax7.set_xlabel("$gt$",**labfont)
    _=ax7.plot(Data3[:-1,0]*g,Data3[:-1,7],ls="-",lw=2,label=labels[0])
    _=ax7.plot(Data[:-1,0]*g,Data[:-1,7],ls="--",lw=2,label=labels[1])
    _=ax7.plot(Data2[:-1,0]*g,Data2[:-1,7],ls="-.",lw=2,label=labels[2])
else:
    _=ax7.set_xlabel("$t/\\tau$",**labfont)
    _=ax7.plot(Data[:-1,0]/tau,Data[:-1,7],ls="-",lw=2,label=labels[0])
    _=ax7.plot(Data2[:-1,0]/tau,Data2[:-1,7],ls="--",lw=2,label=labels[1])
    _=ax7.plot(Data3[:-1,0]/tau,Data3[:-1,7],ls="-.",lw=2,label=labels[2])
_=ax7.set_ylabel("$g^{(2)}_2$",**labfont)
_=ax7.legend()
ax7.grid(True)
_=ax7.set_ylim(-1,13.0)
#_=ax7.set_xlim(-0,200.)
_=ax7.set_xlim(-0,40.)
_=ax7.legend()
fig7.savefig("../Pictures/lin_ccqed/%d_%d_%d_g2_2.png"%(num[0],num[1],num[2]))

# %%
fig3 = plt.figure(dpi=200)
ax3 = fig3.add_subplot(111)
if tau_case:
    _=ax3.set_xlabel("$gt$",**labfont)
    _=ax3.plot(Data3[:-1,0]*g,Data3[:-1,2],ls="-",lw=2,label=labels[0])
    _=ax3.plot(Data[:-1,0]*g,Data[:-1,2],ls="--",lw=2,label=labels[1])
    _=ax3.plot(Data2[:-1,0]*g,Data2[:-1,2],ls="-.",lw=2,label=labels[2])
else:
    _=ax3.set_xlabel("$t/\\tau$",**labfont)
    _=ax3.plot(Data[:-1,0]/tau,Data[:-1,2],ls="-",lw=2,label=labels[0])
    _=ax3.plot(Data2[:-1,0]/tau,Data2[:-1,2],ls="--",lw=2,label=labels[1])
    _=ax3.plot(Data3[:-1,0]/tau,Data3[:-1,2],ls="-.",lw=2,label=labels[2])
_=ax3.set_ylabel("Atomic population (left)",**labfont)
_=ax3.legend()
ax3.grid(True)
_=ax3.set_ylim(-1.1,1.1)
_=ax3.set_xlim(-0,1000.)
#_=ax3.set_xlim(-0,60.)

fig4 = plt.figure(dpi=200)
ax4 = fig4.add_subplot(111)
if tau_case:
    _=ax4.set_xlabel("$gt$",**labfont)
    _=ax4.plot(Data3[:-1,0]*g,Data3[:-1,3],ls="-",lw=2,label=labels[0])
    _=ax4.plot(Data[:-1,0]*g,Data[:-1,3],ls="--",lw=2,label=labels[1])
    _=ax4.plot(Data2[:-1,0]*g,Data2[:-1,3],ls="-.",lw=2,label=labels[2])
else:
    _=ax4.set_xlabel("$t/\\tau$",**labfont)
    _=ax4.plot(Data[:-1,0]/tau,Data[:-1,3],ls="-",lw=2,label=labels[0])
    _=ax4.plot(Data2[:-1,0]/tau,Data2[:-1,3],ls="--",lw=2,label=labels[1])
    _=ax4.plot(Data3[:-1,0]/tau,Data3[:-1,3],ls="-.",lw=2,label=labels[2])
_=ax4.set_ylabel("Atomic population (right)",**labfont)
_=ax4.legend()
ax4.grid(True)
_=ax4.set_ylim(-1.1,1.1)
_=ax4.set_xlim(-0,1000.)
#_=ax4.set_xlim(-0,60.)
_=ax4.legend()

# %%
fig, ((ax11, ax12, ax13)) = plt.subplots(3, 1, sharex=True, sharey=True,dpi=200)
#ax11 = fig1.add_subplot(111)
#ax12 = fig1.add_subplot(211)
#ax13 = fig1.add_subplot(311)
if tau_case:
    _=ax13.set_xlabel("$gt$",**labfont)
    _=ax11.plot(Data3[:-1,0]*g,Data3[:-1,4],ls="-",lw=2,label=labels[0])
    _=ax12.plot(Data[:-1,0]*g,Data[:-1,4]-1,ls="--",lw=2,label=labels[0])
    _=ax12.plot(Data[:-1,0]*g,Data[:-1,4],ls="--",lw=2,label=labels[1])
    _=ax13.plot(Data2[:-1,0]*g,Data2[:-1,4]-1,ls="-.",lw=2,label=labels[0])
    _=ax13.plot(Data2[:-1,0]*g,Data2[:-1,4]-1,ls="-.",lw=2,label=labels[1])
    _=ax13.plot(Data2[:-1,0]*g,Data2[:-1,4],ls="-.",lw=2,label=labels[2])
else:
    _=ax13.set_xlabel("$t/\\tau$",**labfont)
    _=ax11.plot(Data[:-1,0]/tau,Data[:-1,4],ls="-",lw=2,label=labels[0])
    _=ax12.plot(Data2[:-1,0]/tau,Data2[:-1,4],ls="--",lw=2,label=labels[1])
    _=ax13.plot(Data3[:-1,0]/tau,Data3[:-1,4],ls="-.",lw=2,label=labels[2])
_=fig.text(0.04, 0.5, 'Cavity 1 occupation', va='center', rotation='vertical',**labfont)
    #_=ax11.set_ylabel("Cavity 1 occupation",**labfont)
#_=ax12.set_ylabel("Cavity 1 occupation",**labfont)
#_=ax13.set_ylabel("Cavity 1 occupation",**labfont)
_=ax13.legend(loc=(.75,2.6))
ax11.grid(True)
ax12.grid(True)
ax13.grid(True)
_=ax11.set_ylim(-.05,.5)
_=ax12.set_ylim(-.05,.5)
_=ax13.set_ylim(-.05,.5)
#_=ax1.set_xlim(-0,600.)
_=ax11.set_xlim(-0,60.)
_=ax12.set_xlim(-0,60.)
_=ax13.set_xlim(-0,60.)

# %%
Data = np.zeros((190,8))
Data[:,:] = np.genfromtxt('./Data/CCQED+fb_3.txt')
plt.figure(0,figsize=(9,6))
plt.plot(Data[:151,0],Data[:151,1])
plt.figure(1,figsize=(9,6))
plt.plot(Data[:151,0],Data[:151,4])
plt.xlabel("$t$",**labfont)
plt.plot(Data[:151,0],Data[:151,5])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle N_{cav}\rangle$",**labfont)
plt.grid(True)
plt.figure(2,figsize=(9,6))
plt.plot(Data[:151,0],Data[:151,2])
plt.xlabel("$t$",**labfont)
plt.plot(Data[:151,0],Data[:151,3])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle\sigma_z\rangle$",**labfont)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-80-cab78b5cc8a3> in <module>()
#       1 Data = np.zeros((190,8))
# ----> 2 Data[:,:] = np.genfromtxt('./Data/CCQED+fb_3.txt')
#       3 plt.figure(0,figsize=(9,6))
#       4 plt.plot(Data[:151,0],Data[:151,1])
#       5 plt.figure(1,figsize=(9,6))
#
# ~/Documents/anaconda3/envs/py35/lib/python3.5/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1549                 fhd = iter(np.lib._datasource.open(fname, 'rbU'))
#    1550             else:
# -> 1551                 fhd = iter(np.lib._datasource.open(fname, 'rb'))
#    1552             own_fhd = True
# ...

# %%
len_env=5
gcdiag = np.zeros(len_env,complex)
for i in range(1,len_env):
    gcdiag[i] = gcdiag[i-1]+2*(i-1)
    print(gcdiag)
g2c    = np.diag(np.sort(np.concatenate((gcdiag[:-1],gcdiag))))
print(g2c)
# Out:
# [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
# [ 0.+0.j  0.+0.j  2.+0.j  0.+0.j  0.+0.j]
# [ 0.+0.j  0.+0.j  2.+0.j  6.+0.j  0.+0.j]
# [  0.+0.j   0.+0.j   2.+0.j   6.+0.j  12.+0.j]
# [[  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   2.+0.j   0.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   2.+0.j   0.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   6.+0.j   0.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   6.+0.j
#     0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j   0.+0.j
#    12.+0.j]]

# %%
Data = np.zeros((200,8))
Data[:,:] = np.genfromtxt('./Data/CCQED+fb_3.txt')
plt.figure(0,figsize=(9,6))
plt.plot(Data[:,0],Data[:,1])
plt.figure(1,figsize=(9,6))
plt.plot(Data[:,0],Data[:,4])
plt.xlabel("$t$",**labfont)
plt.plot(Data[:,0],Data[:,5])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle N_{cav}\rangle$",**labfont)
plt.grid(True)
plt.figure(2,figsize=(9,6))
plt.plot(Data[:,0],Data[:,2])
plt.xlabel("$t$",**labfont)
plt.plot(Data[:,0],Data[:,3])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle\sigma_z\rangle$",**labfont)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-842a05442db9> in <module>()
#       1 Data = np.zeros((200,8))
# ----> 2 Data[:,:] = np.genfromtxt('./Data/CCQED+fb_3.txt')
#       3 plt.figure(0,figsize=(9,6))
#       4 plt.plot(Data[:,0],Data[:,1])
#       5 plt.figure(1,figsize=(9,6))
#
# ~/Documents/anaconda3/envs/py35/lib/python3.5/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1549                 fhd = iter(np.lib._datasource.open(fname, 'rbU'))
#    1550             else:
# -> 1551                 fhd = iter(np.lib._datasource.open(fname, 'rb'))
#    1552             own_fhd = True
# ...

# %%
Data = np.zeros((133,8))
Data[:,:] = np.genfromtxt('./Data/CCQED+fb_4.txt')
plt.figure(0,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,1])
plt.figure(1,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,4])
plt.xlabel("$t/2\pi$",**labfont)
plt.plot(Data[:,0]/2/np.pi,Data[:,5])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle N_{cav}\rangle$",**labfont)
plt.grid(True)
plt.figure(2,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,2])
plt.xlabel("$t/2\pi$",**labfont)
plt.plot(Data[:,0]/2/np.pi,Data[:,3])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle\sigma_z\rangle$",**labfont)
plt.grid(True)
plt.show()
# Out:
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle N_{cav}\\rangle$')
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle\\sigma_z\\rangle$')

# %%
Data = np.zeros((238,8))
Data[:,:] = np.genfromtxt('./Data/CCQED+fb_5.txt')
plt.figure(0,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,1])
plt.figure(1,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,4])
plt.xlabel("$t/2\pi$",**labfont)
plt.plot(Data[:,0]/2/np.pi,Data[:,5])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle N_{cav}\rangle$",**labfont)
plt.grid(True)
plt.figure(2,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,2])
plt.xlabel("$t/2\pi$",**labfont)
plt.plot(Data[:,0]/2/np.pi,Data[:,3])
plt.legend(["left","right"],fontsize = 20)
plt.ylabel(r"$\langle\sigma_z\rangle$",**labfont)
plt.grid(True)
plt.show()
# Out:
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle N_{cav}\\rangle$')
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle\\sigma_z\\rangle$')

# %%
Data = np.zeros((1001,8))
Data[:,:] = np.genfromtxt('./Data/CCQED/CCQED+fb_6.txt')
Data2 = np.zeros((1001,5))
Data2[:,:] = np.genfromtxt('./CCQED_MC.txt')
plt.figure(0,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,1])
plt.figure(1,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,4])
plt.xlabel("$t/2\pi$",**labfont)
plt.plot(Data[:,0]/2/np.pi,Data[:,5])
plt.plot(Data2[:,0],Data2[:,3],ls="--")
plt.plot(Data2[:,0],Data2[:,4],ls="--")
plt.legend(["left","right","left MC","right MC"],fontsize = 20,loc = (1.05,0.5))
plt.ylabel(r"$\langle N_{cav}\rangle$",**labfont)
plt.grid(True)
plt.figure(2,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,2])
plt.xlabel("$t/2\pi$",**labfont)
plt.plot(Data[:,0]/2/np.pi,Data[:,3])
plt.plot(Data2[:,0],Data2[:,1],ls="--")
plt.plot(Data2[:,0],Data2[:,2],ls="--")
plt.legend(["left","right","left MC","right MC"],fontsize = 20,loc = (1.05,0.5))
plt.ylabel(r"$\langle\sigma_z\rangle$",**labfont)
plt.grid(True)
plt.show()
# Out:
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle N_{cav}\\rangle$')
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle\\sigma_z\\rangle$')
# C:\Users\Niki\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['FreeSerif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
Data = np.zeros((1322,8))
Data[:,:] = np.genfromtxt('./Data/CCQED/Cluster/CCQED+fb_7.txt')
#Data[:,:] = np.genfromtxt('./Data/CCQED+fb_par_11.txt')
Data2 = np.zeros((1001,5))
Data2[:,:] = np.genfromtxt('./CCQED_MC11_.txt')
Data3 = np.zeros((1001,5))
Data3[:,:] = np.genfromtxt('./CCQED_MC11_diss.txt')
plt.figure(0,figsize=(9,6))
plt.plot(Data[:,0]/2/np.pi,Data[:,1],lw=3)
plt.figure(1,figsize=(9,6))
plt.plot(Data2[:,0],Data2[:,3],ls="--",lw=3)
plt.plot(Data3[:,0],Data3[:,3],ls=":",lw=4)
plt.plot(Data[:,0]/2/np.pi,Data[:,4],lw=3)
plt.xlabel("$t/2\pi$",**labfont)
plt.legend(["fibre as cavity","fibre as reservoir","MPS"],fontsize = 20)
plt.ylabel(r"$\langle N_{cav,1}\rangle$",**labfont)
plt.grid(True)
plt.figure(2,figsize=(9,6))
plt.plot(Data2[:,0],Data2[:,4],ls="--",lw=3)
plt.plot(Data3[:,0],Data3[:,4],ls=":",lw=4)
plt.plot(Data[:,0]/2/np.pi,Data[:,5],lw=3)
plt.xlabel("$t/2\pi$",**labfont)
plt.legend(["fibre as cavity","fibre as reservoir","MPS"],fontsize = 20)
plt.ylabel(r"$\langle N_{cav,2}\rangle$",**labfont)
plt.grid(True)
plt.figure(3,figsize=(9,6))
plt.plot(Data2[:,0],Data2[:,1],ls="--",lw=3)
plt.plot(Data3[:,0],Data3[:,1],ls=":",lw=4)
plt.plot(Data[:,0]/2/np.pi,Data[:,2],lw=3)
plt.xlabel("$t/2\pi$",**labfont)
plt.legend(["fibre as cavity","fibre as reservoir","MPS"],fontsize = 20)
plt.grid(True)
plt.ylabel(r"$\langle\sigma_{z,1}\rangle$",**labfont)
plt.figure(4,figsize=(9,6))
plt.plot(Data2[:,0],Data2[:,2],ls="--",lw=3)
plt.plot(Data3[:,0],Data3[:,2],ls=":",lw=4)
plt.plot(Data[:,0]/2/np.pi,Data[:,3],lw=3)
plt.xlabel("$t/2\pi$",**labfont)
plt.legend(["fibre as cavity","fibre as reservoir","MPS"],fontsize = 20)
plt.grid(True)
plt.ylabel(r"$\langle\sigma_{z,2}\rangle$",**labfont)
plt.show()
plt.show()
plt.show()
plt.show()
# Out:
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle N_{cav,1}\\rangle$')
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle N_{cav,2}\\rangle$')
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle\\sigma_{z,1}\\rangle$')
# Text(0.5,0,'$t/2\\pi$')
# Text(0,0.5,'$\\langle\\sigma_{z,2}\\rangle$')
# C:\Users\Niki\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['FreeSerif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
A = np.linspace(0,15,16).reshape((4,4))
A[2,0] = A[2,0]/0
A[3,3] = np.sqrt(-2)

def vmi(mat):
    mat = np.nan_to_num(mat,copy=False)
    return mat

B = vmi(A)
print(A)
print(B)
# Out:
# [[  0.00000000e+000   1.00000000e+000   2.00000000e+000   3.00000000e+000]
#  [  4.00000000e+000   5.00000000e+000   6.00000000e+000   7.00000000e+000]
#  [  1.79769313e+308   9.00000000e+000   1.00000000e+001   1.10000000e+001]
#  [  1.20000000e+001   1.30000000e+001   1.40000000e+001   0.00000000e+000]]
# [[  0.00000000e+000   1.00000000e+000   2.00000000e+000   3.00000000e+000]
#  [  4.00000000e+000   5.00000000e+000   6.00000000e+000   7.00000000e+000]
#  [  1.79769313e+308   9.00000000e+000   1.00000000e+001   1.10000000e+001]
#  [  1.20000000e+001   1.30000000e+001   1.40000000e+001   0.00000000e+000]]
# /home/nnem614/Documents/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars
#
# /home/nnem614/Documents/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
# ...
